# %% [markdown]
# # Orders

# %%
import requests
import pandas as pd
import json
import time
from datetime import date

# %%
# Склад остатки - stocks?dateFrom=2023-04-12
# Заказы        - orders?dateFrom=2023-02-09&flag=0
# Продажи       - sales?dateFrom=2023-02-09&flag=0
# Поставки      - incomes?dateFrom=2023-03-19
# Отчет о продажах по реализации - reportDetailByPeriod?dateFrom=2023-02-09&dateTo=2023-02-28

# %%
# Выгружаем данные
# На выходе получается строка с информацие в виде словаря
url = "https://statistics-api.wildberries.ru/api/v1/supplier/orders?dateFrom=2023-01-01&flag=0"
payload = {}
headers = {
  'Authorization': ''
}
response = requests.request("GET", url, headers=headers, data=payload)
print(response.text)

# %% [markdown]
# # Предварительная обработка таблицы

# %%
# Данные в переменную
str_total = response.text  # достаём данные в строку
str_total

# %%
# Создаём первую строку датафрэйма
# Убираем лишние символы, разбиваем, берём первый заказ, добавляем символы для словаря
s_first = '{' + str_total.replace('[', '').replace(']', '').split('},{')[0].replace('{', '').replace('}', '') + '}'
# преобразуем словарь
json_acceptable_string = s_first.replace('"', "\"")
data = json.loads(json_acceptable_string)
# словарь в дф
df = pd.DataFrame([data])
df
# Out:
#                   date       lastChangeDate   supplierArticle techSize  \
# 0  2023-02-22T13:18:54  2023-02-22T23:41:08  Этнический халат     XS-L
#
#          barcode  totalPrice  discountPercent warehouseName  oblast  incomeID  \
# 0  2037488839493        6400               41      Коледино  Москва  10960235
#
#             odid       nmId          subject category brand  isCancel  \
# 0  9001947819539  147263932  Халаты домашние   Одежда           False
#
#              cancel_dt               gNumber sticker                   srid
# 0  0001-01-01T00:00:00  96772691678002781140          17823514073508166.1.0

# %%
# Проходимся циклом по строке и дополняем датафрэйм
# Запускать 1 раз!
str_need = str_total.split('},{')
for i in str_need[1:]:  # Со второго элемента, так как первый уже закинул в дф
    i = '{' + i.replace('[', '').replace(']', '').replace('{', '').replace('}', '') + '}'
    json_acceptable_string = i.replace('"', "\"")
    data = json.loads(json_acceptable_string)
    df_t = pd.DataFrame([data])
    df = pd.concat([df, df_t])
df = df.reset_index(drop=True)
df.head(3)
# Out:
#                   date       lastChangeDate   supplierArticle techSize  \
# 0  2023-02-22T13:18:54  2023-02-22T23:41:08  Этнический халат     XS-L
# 1  2023-02-23T07:29:53  2023-02-23T12:35:43  Этнический халат     XS-L
# 2  2023-02-23T08:03:16  2023-02-23T12:41:55       Синий халат     XS-L
#
#          barcode  totalPrice  discountPercent warehouseName  oblast  incomeID  \
# 0  2037488839493      6400.0               41      Коледино  Москва  10960235
# 1  2037488839493      6400.0               41      Коледино  Москва  10960235
# 2  2037488779201      5800.0               36      Коледино  Москва  10960235
#
#             odid       nmId          subject category brand  isCancel  \
# 0  9001947819539  147263932  Халаты домашние   Одежда           False
# 1  9001954570071  147263932  Халаты домашние   Одежда           False
# 2  9001954710126  147263461  Халаты домашние   Одежда           False
#
#              cancel_dt               gNumber sticker  \
# 0  0001-01-01T00:00:00  96772691678002781140
# 1  0001-01-01T00:00:00    200213017041704931
# 2  0001-01-01T00:00:00  96805883299484393157
#
#                                srid
# 0             17823514073508166.1.0
# 1  9fe31f11007e4d46b63772885572e81e
# 2  1501293d1455454cb2551f51415fc133

# %%
date - дата
gNumber - Номер заказа. Объединяет все позиции одного заказа.
supplierArticle - артикуль
techSize - размер
totalPrice - Цена до согласованной итоговой скидки/промо/спп.
discountPercent - Согласованный итоговый дисконт.
incomeID - Номер поставки (от продавца на склад)
! odid - Уникальный идентификатор позиции заказа. Может использоваться для поиска соответствия между заказами и продажами.
nmId - Артикул WB
subject - Предмет
isCancel - Отмена заказа. true - заказ отменен до оплаты.
cancel_dt - Дата и время отмены заказа
srid - Уникальный идентификатор заказа, функционально аналогичный odid/rid
# Out:
#   File "C:\Users\Test\AppData\Local\Temp\ipykernel_6788\4055317334.py", line 4
#     totalPrice - Цена до согласованной итоговой скидки/промо/спп.
#                       ^
# SyntaxError: invalid syntax

# %%
# Создали колонку с датами заказа / отмены заказа
df = df.assign(date_corr = df.date.apply(lambda x: x.split('T')[0]))
df = df.assign(cancel_date = df.cancel_dt.apply(lambda x: x.split('T')[0]))

# %%
# Даты в тип с датой покупки
df['date_corr'] = pd.to_datetime(df['date_corr'],format='%Y-%m-%d')
# С колонкой даты по возврату нужно немного помучиться
# Невозможно загнать в дату число '0001-01-01'
def date_canc_func(row):
    if row == '0001-01-01':
        return '2023-02-22'
    else:
        return row
df['cancel_date'] = df['cancel_date'].apply(date_canc_func)
df['cancel_date'] = pd.to_datetime(df['cancel_date'],format='%Y-%m-%d')

# %%
# Оставляем нужные колонки
df = df[['date_corr', 'gNumber', 'srid', 'supplierArticle', 'techSize', 'totalPrice', 'discountPercent', 'incomeID',  \
         'odid', 'nmId', 'subject', 'isCancel', 'cancel_date']].copy()

# %%
# Добавали цены со скидкой - priceWithDiscount
df['priceWithDiscount'] = df.totalPrice * (1 - df.discountPercent / 100)

# %%
# Колонку с отменой откорректировали
df['isCancel'] = df['isCancel'] * 1

# %%
# Сохраним файл
today = date.today()
df.to_excel(f'orders_{today}.xlsx', index=False)
df.to_csv(f'orders_{today}.csv', index=False)

# %% [markdown]
# # Исследование данных

# %%
# Заказы, где несколько позиций
df.groupby('gNumber', as_index=False).agg({'supplierArticle' : 'count'})  \
    .sort_values('supplierArticle', ascending=False).head(10)
# Out:
#                   gNumber  supplierArticle
# 76    9012704706841939191                4
# 146  96992784473039596159                3
# 100  92889767614462014074                3
# 45    5879849442884060468                2
# 1     1105333839752510442                2
# 61     735160258708416067                2
# 165   9890115709619529856                2
# 33       4167807836533536                2
# 17    2859805610539408127                2
# 117  94527030776146887138                1

# %%
# Отменённые заказы
cancelled = df[df.isCancel == True]
cancelled
# Out:
#      date_corr               gNumber                              srid  \
# 21  2023-03-01   5130338983342920726  2e0e15f9028d4c04ac858e617113e588
# 26  2023-03-04  91289940096818655628  b6a448df0b3f4fb2bdd62eb296de13b3
# 29  2023-03-08   8849912591178972883             12918656074130752.0.0
# 31  2023-03-11  93460505466031179453  e6509d74b8224f0da6692a021bee2fa4
# 36  2023-03-10   4027202863189022883  d80b2d99f4ff406fbfa46e688577f8d7
# 37  2023-03-12   8826096817396535016             15628841574293186.2.0
# 38  2023-03-10   2821973071259241728             55632537074198579.1.0
# 42  2023-03-12   9946999397790708657             18124248074278511.0.0
# 44  2023-03-13  94791398545829743066  8b8c5f525e204413a9277e80840e1355
# 45  2023-03-15  97883735890419337050  5412c0e9722049b4bf2a2de18546970d
# 55  2023-03-18  97363729120300369227  5d1b8eff3a1345fe8243fc32bc78f9ee
# 61  2023-03-20  97376515298564973086             25973000074631062.1.0
# 62  2023-03-16   9176300057434369392             16728859074467187.0.0
# 68  2023-03-26   9166241319348474531             11098409074867571.0.0
# 71  2023-03-29  94788786441431824563             29241817075024463.5.0
# 77  2023-03-31   1896130668174483372             17689134575120940.0.0
# 79  2023-04-03  95673007002055463109             18305302575253982.1.0
# 84  2023-04-01  95710963061664263727             18984135575155881.0.0
# 86  2023-04-06   3207083385488525453             16571355075377487.2.0
# 90  2023-04-14  95407516405626075387             16015649075703597.0.0
# 95  2023-04-20   3428664139730817680             23916498075965227.0.0
# 99  2023-04-27    420084278131193677  3520c8ebb2d54913b0898b6b30715fc1
# 102 2023-05-01  96784181073039382430             25615259076464330.1.0
# 105 2023-05-01  95030035644583497445  c8aeda83e9df41b0b4770a0aeb9658e7
# 119 2023-05-18  94190862224790757974  ab0c9d535d2a4370bc48cbdfe52a18e6
# 120 2023-05-17  91965352110695287304             15768537577148697.0.0
# 121 2023-05-17   6250859661326893798             10145916077125420.1.0
# 124 2023-05-24   9237732292479531636             26094069577441420.0.0
# 127 2023-05-10   9885403778240846556             13557390576828931.0.0
# 129 2023-05-27   3526186073374936058             15261631077579326.0.0
# 133 2023-05-27   8623664380052255739             15589532077563492.2.0
# 135 2023-05-31   8069078382288517320             19810369577719446.0.0
# 136 2023-05-31    805419244886179983             14476526077753178.0.0
# 139 2023-05-31  93467080698820708079             16025594577757126.0.0
# 142 2023-06-04   7773307997093496443  9e15782165f24c87b56aabab761d124f
# 151 2023-06-06   5044152723538397173  52151fd01be7462eb4087d543c68a3dd
# 153 2023-06-07  91676764135286567074             18688753578050777.0.0
# 156 2023-06-08   2772167109691951215  fda23fed1b6b4395bc580524fd331dea
# 164 2023-06-07   7279573285074121995             41870259078056301.0.0
# 166 2023-06-07  95866503196743789101             13574318078047530.0.0
# 167 2023-06-07  97828506082994462897             15232156578045924.0.0
# 172 2023-06-09    597987289934663553             38206964578136718.0.0
# 179 2023-06-06  91698129647607942372             27464248077998086.0.0
# 180 2023-06-07   8987839023707364310             27464248078049217.0.0
# 181 2023-06-13   1105333839752510442             17103026078313221.1.0
# 182 2023-06-13   1105333839752510442             17103026078313221.0.0
# 183 2023-06-08  99121013222493338588             11466600578078571.5.0
#
#                   supplierArticle techSize  totalPrice  discountPercent  \
# 21                    Синий халат     XS-L     5800.00               36
# 26                    Синий халат     XS-L     4803.13               36
# 29               Этнический халат     XS-L     6400.00               41
# 31               Этнический халат     XS-L     6400.00               48
# 36               Этнический халат     XS-L     6400.00               41
# 37   Шелковая пижама белые листья     XS-L     6700.00               62
# 38   Шелковая пижама белые листья     XS-L     6700.00               49
# 42                    Синий халат     XS-L     5800.00               57
# 44               Этнический халат     XS-L     6400.00               48
# 45               Этнический халат     XS-L     6400.00               48
# 55               Этнический халат     XS-L     6400.00               40
# 61               Этнический халат     XS-L     6400.00               48
# 62               Этнический халат     XS-L     6400.00               39
# 68               Этнический халат     XS-L     6400.00               53
# 71                    Синий халат     XS-L     5800.00               70
# 77                    Синий халат     XS-L     5800.00               75
# 79                    Синий халат     XS-L     5800.00               74
# 84                 черный журавли     XS-L     5800.00               65
# 86               Этнический халат     XS-L     7956.76               63
# 90          Шелковая пижама лист1     XS-L     8079.41               66
# 95          Шелковая пижама лист1     XS-L     8007.32               59
# 99                 черный журавли     XS-L     7068.75               68
# 102              Этнический халат     XS-L     7644.44               64
# 105              Этнический халат     XS-L     7644.44               64
# 119              Этнический халат     XS-L     7444.90               51
# 120                   Синий халат     XS-L     6659.26               73
# 121              Этнический халат     XS-L     7444.90               51
# 124         Шелковая пижама лист1     XS-L     7855.17               71
# 127                    Голубалдеж     XS-S     7575.51               51
# 129                    Голубалдеж     XS-S     8000.00               52
# 133                    розовежник      M-L     7836.73               51
# 135                    Голубалдеж     XS-S     8145.45               45
# 136              Этнический халат     XS-L     8273.17               59
# 139              Этнический халат     XS-L     8273.17               59
# 142              Этнический халат     XS-L     8306.38               53
# 151              Этнический халат     XS-L     8334.88               57
# 153              Этнический халат   L-XXXL     8533.33               70
# 156              Этнический халат   L-XXXL     8533.33               70
# 164              Этнический халат   L-XXXL     8533.33               70
# 166              Этнический халат   L-XXXL     8258.06               69
# 167              Этнический халат     XS-L     8258.06               69
# 172                    розовежник      M-L     8452.83               47
# 179              Этнический халат   L-XXXL     8334.88               57
# 180              Этнический халат   L-XXXL     8258.06               69
# 181              Этнический халат     XS-М     8697.44               61
# 182                   Синий халат     XS-L     7733.33               79
# 183              Этнический халат     XS-L     8533.33               70
#
#      incomeID           odid       nmId          subject  isCancel  \
# 21   10960235  9002020765959  147263461  Халаты домашние         1
# 26   10960235  9002051705309  147263461  Халаты домашние         1
# 29          0  9002101113782  147263932  Халаты домашние         1
# 31   10960235  9002126207609  147263932  Халаты домашние         1
# 36   10960235  9002114019805  147263932  Халаты домашние         1
# 37   10960235  9002138456427  147271347           Пижамы         1
# 38   10960235  9002114995693  147271347           Пижамы         1
# 42   10960235  9002133073778  147263461  Халаты домашние         1
# 44   10960235  9002148289742  147263932  Халаты домашние         1
# 45   10960235  9002166892667  147263932  Халаты домашние         1
# 55   10960235  9002196513135  147263932  Халаты домашние         1
# 61   10960235  9002214531762  147263932  Халаты домашние         1
# 62   10960235  9002178901068  147263932  Халаты домашние         1
# 68   10960235  9002271582887  147263932  Халаты домашние         1
# 71   10960235  9002307606332  147263461  Халаты домашние         1
# 77   10960235  9002330483066  147263461  Халаты домашние         1
# 79   10960235  9002363002272  147263461  Халаты домашние         1
# 84   11211020  9002337800077  150055859  Халаты домашние         1
# 86   10960235  9002392943615  147263932  Халаты домашние         1
# 90   10960235  9002473864989  147271346           Пижамы         1
# 95   10960235  9002534673390  147271346           Пижамы         1
# 99   11211020  9002614225783  150055859  Халаты домашние         1
# 102  10960235  9002660597206  147263932  Халаты домашние         1
# 105  10960235  9002660286486  147263932  Халаты домашние         1
# 119  10960235  9002833989211  147263932  Халаты домашние         1
# 120         0  9002830770930  147263461  Халаты домашние         1
# 121  10960235  9002823206386  147263932  Халаты домашние         1
# 124  10960235  9002901051127  147271346           Пижамы         1
# 127  12206148  9002748546954  159411808          Костюмы         1
# 129  12206148  9002935720916  159411808          Костюмы         1
# 133  12206148  9002930476182  159411809          Костюмы         1
# 135  12206148  9002971368569  159411808          Костюмы         1
# 136  10960235  9002979752348  147263932  Халаты домашние         1
# 139  10960235  9002981189413  147263932  Халаты домашние         1
# 142  12206148  9003023654160  147263932  Халаты домашние         1
# 151  12696490  9003044935131  147263932  Халаты домашние         1
# 153  12696490  9003057190661  147263932  Халаты домашние         1
# 156  12696490  9003063447628  147263932  Халаты домашние         1
# 164  12696490  9003059156596  147263932  Халаты домашние         1
# 166  12696490  9003056030694  147263932  Халаты домашние         1
# 167  12696490  9003055430988  147263932  Халаты домашние         1
# 172  12206148  9003082642390  159411809          Костюмы         1
# 179  12696490  9003042198144  147263932  Халаты домашние         1
# 180  12696490  9003056633058  147263932  Халаты домашние         1
# 181         0  9003125595402  147263932  Халаты домашние         1
# 182  10960235  9003125629043  147263461  Халаты домашние         1
# 183  12696490  9003063287351  147263932  Халаты домашние         1
#
#     cancel_date  priceWithDiscount
# 21   2023-03-03          3712.0000
# 26   2023-03-07          3074.0032
# 29   2023-03-10          3776.0000
# 31   2023-03-12          3328.0000
# 36   2023-03-13          3776.0000
# 37   2023-03-13          2546.0000
# 38   2023-03-13          3417.0000
# 42   2023-03-15          2494.0000
# 44   2023-03-16          3328.0000
# 45   2023-03-17          3328.0000
# 55   2023-03-20          3840.0000
# 61   2023-03-22          3328.0000
# 62   2023-03-22          3904.0000
# 68   2023-03-29          3008.0000
# 71   2023-04-01          1740.0000
# 77   2023-04-03          1450.0000
# 79   2023-04-04          1508.0000
# 84   2023-04-08          2030.0000
# 86   2023-04-14          2944.0012
# 90   2023-04-16          2746.9994
# 95   2023-04-21          3283.0012
# 99   2023-05-02          2262.0000
# 102  2023-05-06          2751.9984
# 105  2023-05-09          2751.9984
# 119  2023-05-22          3648.0010
# 120  2023-05-22          1798.0002
# 121  2023-05-23          3648.0010
# 124  2023-05-25          2277.9993
# 127  2023-05-28          3711.9999
# 129  2023-05-29          3840.0000
# 133  2023-06-02          3839.9977
# 135  2023-06-03          4479.9975
# 136  2023-06-04          3391.9997
# 139  2023-06-05          3391.9997
# 142  2023-06-07          3903.9986
# 151  2023-06-08          3583.9984
# 153  2023-06-09          2559.9990
# 156  2023-06-11          2559.9990
# 164  2023-06-13          2559.9990
# 166  2023-06-13          2559.9986
# 167  2023-06-13          2559.9986
# 172  2023-06-14          4479.9999
# 179  2023-06-15          3583.9984
# 180  2023-06-15          2559.9986
# 181  2023-06-16          3392.0016
# 182  2023-06-16          1623.9993
# 183  2023-06-16          2559.9990

# %%
# Отменённые заказы в файл
today = date.today()
cancelled.to_excel(f'orders_cancelled_{today}.xlsx', index=False)

# %%
# Топ товаров по отказам с разбивкой по актикулю
t = cancelled.groupby('supplierArticle', as_index=False).agg({'gNumber' : 'count'})  \
    .rename(columns = {'gNumber': 'quant_cancelled'})
m = df.groupby('supplierArticle', as_index=False).agg({'gNumber' : 'count'}).rename(columns = {'gNumber':'total_order'})
s = m.merge(t, how='left', on='supplierArticle').fillna(0)
s['cancel_prc'] = s.quant_cancelled / s.total_order * 100
s.sort_values('cancel_prc', ascending=False)
# Out:
#                  supplierArticle  total_order  quant_cancelled  cancel_prc
# 9                     розовежник            3              2.0   66.666667
# 10                черный журавли            5              2.0   40.000000
# 8               Этнический халат           85             25.0   29.411765
# 6   Шелковая пижама белые листья            7              2.0   28.571429
# 2                    Синий халат           35              7.0   20.000000
# 7          Шелковая пижама лист1           18              3.0   16.666667
# 0                     Голубалдеж           19              3.0   15.789474
# 1                        Красный            2              0.0    0.000000
# 3                          Тигры            2              0.0    0.000000
# 4                      Цвет ЗАРА            4              0.0    0.000000
# 5                    Черно-белый            4              0.0    0.000000

# %%
# Топ товаров по отказам с разбивкой по размерам
t = cancelled.groupby('techSize', as_index=False).agg({'gNumber' : 'count'})  \
    .rename(columns = {'gNumber': 'quant_cancelled'})
m = df.groupby('techSize', as_index=False).agg({'gNumber' : 'count'}).rename(columns = {'gNumber':'total_order'})
s = m.merge(t, how='left', on='techSize').fillna(0)
s['cancel_prc'] = s.quant_cancelled / s.total_order * 100
s.sort_values('cancel_prc', ascending=False)
# Out:
#   techSize  total_order  quant_cancelled  cancel_prc
# 3     XS-S            9              3.0   33.333333
# 0   L-XXXL           20              6.0   30.000000
# 2     XS-L          137             33.0   24.087591
# 1      M-L           13              2.0   15.384615
# 4     XS-М            5              0.0    0.000000

# %%
# Разбивка количества заказов по месяцам
t = df.sort_values('date_corr').set_index('date_corr').resample(rule='m').techSize.count()  \
    .reset_index().rename(columns={'techSize':'quant_orders'})
t
# Out:
#    date_corr  quant_orders
# 0 2023-02-28            21
# 1 2023-03-31            52
# 2 2023-04-30            27
# 3 2023-05-31            35
# 4 2023-06-30            49

# %%
# Разбивка количества заказов по неделям
t = df.sort_values('date_corr').set_index('date_corr').resample(rule='w').techSize.count()  \
    .reset_index().rename(columns={'techSize':'quant_orders'})
t
# Out:
#     date_corr  quant_orders
# 0  2023-02-26            21
# 1  2023-03-05             4
# 2  2023-03-12            13
# 3  2023-03-19            19
# 4  2023-03-26            11
# 5  2023-04-02            10
# 6  2023-04-09             9
# 7  2023-04-16             5
# 8  2023-04-23             4
# 9  2023-04-30             4
# 10 2023-05-07             4
# 11 2023-05-14             9
# 12 2023-05-21            10
# 13 2023-05-28             8
# 14 2023-06-04             9
# 15 2023-06-11            26
# 16 2023-06-18            18

# %%
# Процент отмены заказов по месяцам
t = df.sort_values('date_corr').set_index('date_corr').resample(rule='m').techSize.count()  \
    .reset_index().rename(columns={'techSize':'quant_orders_total'})
m = df[df.isCancel==True].sort_values('date_corr').set_index('date_corr').resample(rule='m').techSize.count()  \
    .reset_index().rename(columns={'techSize':'quant_orders_cancalled'})
s = m.merge(t, how='left', on='date_corr')
s['prc_cancelled'] = round(s.quant_orders_cancalled / s.quant_orders_total * 100)
s
# Out:
#    date_corr  quant_orders_cancalled  quant_orders_total  prc_cancelled
# 0 2023-03-31                      16                  52           31.0
# 1 2023-04-30                       6                  27           22.0
# 2 2023-05-31                      12                  35           34.0
# 3 2023-06-30                      10                  49           20.0

# %% [markdown]
# # Разное

# %%
# Выгрузка таблицы с перечнем артикулов
df_tov = pd.Series(df.supplierArticle.unique()).to_frame().rename(columns={0:'supplierArticle'})
df_tov['cost'] = 0
#df_tov
df_tov.to_excel('артикулы_себестоимость.xlsx')
# Out:
#                  supplierArticle  cost
# 0               Этнический халат     0
# 1                    Синий халат     0
# 2          Шелковая пижама лист1     0
# 3   Шелковая пижама белые листья     0
# 4                      Цвет ЗАРА     0
# 5                 черный журавли     0
# 6                    Черно-белый     0
# 7                        Красный     0
# 8                          Тигры     0
# 9                     Голубалдеж     0
# 10                    розовежник     0

# %%
# Таблица для расчёта конверсии заказ / выкуп
today = date.today()
df_orders = df[['odid', 'supplierArticle', 'techSize', 'date_corr']].copy()
df_orders = df_orders.sort_values('date_corr').rename(columns={'date_corr': 'data_order'})
df_orders.to_excel(f'orders_{today}_for_conversion.xlsx', index=False)
